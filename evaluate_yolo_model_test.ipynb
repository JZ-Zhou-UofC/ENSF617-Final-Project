# %%
from ultralytics import YOLO

model = YOLO(r"runs\detect\runs\detect_exp\weights\best.pt")

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
metrics = model.val(
    data="data.yaml",
    split="test",
    plots=True
)
# Out:
# Ultralytics 8.4.30  Python-3.13.5 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1818.1609.0 MB/s, size: 223.5 KB)
# val: Scanning D:\617 project\yolo_data_set\labels\test.cache... 88 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 88/88 23.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.2s0.2ss
#                    all         88        133      0.965      0.898      0.918      0.789
#             speedlimit         68         81      0.995          1      0.995      0.933
#              crosswalk         23         25      0.903       0.88      0.923      0.737
#           trafficlight         10         18          1      0.713      0.758      0.552
#                   stop          9          9      0.963          1      0.995      0.933
# ...
